# %% [markdown]
# <a href="https://colab.research.google.com/github/soldier-tn/dic_graduation_work/blob/main/DIC_%E5%8D%92%E6%A5%AD%E8%AA%B2%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DIC卒業課題 - SIGNATEコンペ タダノクレーン旋回操作最適化チャレンジ -

# %% [markdown]
# ## ■概要

# %% [markdown]
# 卒業課題として、クレーンを自動操縦するエージェント開発のコンペに参加した。
#
# コンペ主催者側の規定により開発したソースコードや得られた詳細な知見は公開不可のため、本資料ではコンペの概要のみ記載する。

# %% [markdown]
# ![image.png](data:image/png;base64,...)
